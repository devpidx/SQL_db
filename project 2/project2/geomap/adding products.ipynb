# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('lat_long.xlsx', index_col=0)

# %%
df.columns
# Out:
# Index(['Terminal Owner Name', 'TERMINAL ID', 'Address',
#        'TERMINAL CITY/TOWN/LOCALITY', 'TERMINAL COUNTY/PROVINCE',
#        'TERMINAL POSTAL CODE', 'TERMINAL COUNTRY', 'TERMINAL GEO COORDINATES',
#        'lat', 'long', 'B25'],
#       dtype='object')

# %%
df['B25'] = np.random.randint(10000,60000, size=len(df))

# %%
df['B29'] = np.random.randint(10000,60000, size=len(df))

# %%
df['B37'] = np.random.randint(10000,60000, size=len(df))

# %%
df['B73'] = np.random.randint(10000,60000, size=len(df))

# %%
df['D11'] = np.random.randint(10000,110000, size=len(df))

# %%
df['D2K'] = np.random.randint(10000,110000, size=len(df))

# %%
df['D6N'] = np.random.randint(10000,110000, size=len(df))

# %%
df['D80'] = np.random.randint(10000,110000, size=len(df))

# %%
df['P18'] = np.random.randint(10000,80000, size=len(df))

# %%
df['P2R'] = np.random.randint(10000,80000, size=len(df))

# %%
df['P37'] = np.random.randint(10000,80000, size=len(df))

# %%
df['P42'] = np.random.randint(10000,80000, size=len(df))

# %%
df['O21'] = np.random.randint(10000,90000, size=len(df))

# %%
df['O73'] = np.random.randint(10000,90000, size=len(df))

# %%
df['O8I'] = np.random.randint(10000,90000, size=len(df))

# %%
df['OUB'] = np.random.randint(10000,90000, size=len(df))

# %%
df
# Out:
#                           Terminal Owner Name TERMINAL ID  \
# Submitter
# Shell                 BotanyBay B Vopak depot   TAU000001
# Shell      Botn Vopak BitDepot                  TAU000002
# Shell                    Kwinana Coogee depot   TAU000003
# Shell              Hobart Caltex depot          TAU000004
# Shell                  DarwinEArm Vopak depot   TAU000005
# ...                                       ...         ...
# DTN                                 Jones Oil   TIE000024
# DTN                                 Jones Oil   TIE000025
# DTN                                 Jones Oil   TIE000026
# DTN                                 Jones Oil   TIE000027
# DTN                                 Jones Oil   TIE000028
#
#                                   Address TERMINAL CITY/TOWN/LOCALITY  \
# Submitter
# Shell      49 Friendship Road               Port Botany
# Shell      Unwin Street                       Granville
# Shell      Patterson Road                   Kwinana
# ...

# %%
df.to_excel("product_data.xlsx")
